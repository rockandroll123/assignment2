# %%
import os
input_folder = r"E:/DevData/tiny-imagenet-200/train/"
output_folder = r"E:/DevData/tiny-imagenet-200-32/train/"
sub_folders = os.listdir(input_folder)

# %%
for i in range(0,len(sub_folders)):
    i_f = input_folder+str(sub_folders[i])+"/images/"
    o_f = output_folder+str(sub_folders[i])
    # os.mkdir(output_folder+str(sub_folders[i]))
    command = "python image_resizer_imagent.py -i "+i_f+" -o "+o_f+" -s 32 -a box -j 10"

    print(command)
    os.system(command)
# Out:
# ren E:/DevData/tiny-imagenet-200-32/train/n01443537/box imagesE:/DevData/tiny-imagenet-200-32/train/n01443537\box
# ren E:/DevData/tiny-imagenet-200-32/train/n01629819/box imagesE:/DevData/tiny-imagenet-200-32/train/n01629819\box
# ren E:/DevData/tiny-imagenet-200-32/train/n01641577/box imagesE:/DevData/tiny-imagenet-200-32/train/n01641577\box
# ren E:/DevData/tiny-imagenet-200-32/train/n01644900/box imagesE:/DevData/tiny-imagenet-200-32/train/n01644900\box
# ren E:/DevData/tiny-imagenet-200-32/train/n01698640/box imagesE:/DevData/tiny-imagenet-200-32/train/n01698640\box
# ren E:/DevData/tiny-imagenet-200-32/train/n01742172/box imagesE:/DevData/tiny-imagenet-200-32/train/n01742172\box
# ren E:/DevData/tiny-imagenet-200-32/train/n01768244/box imagesE:/DevData/tiny-imagenet-200-32/train/n01768244\box
# ren E:/DevData/tiny-imagenet-200-32/train/n01770393/box imagesE:/DevData/tiny-imagenet-200-32/train/n01770393\box
# ...

# %%
input_folder2 = 'E:\\DevData\\tiny-imagenet-200\\train\\'
output_folder2 = "E:\\DevData\\tiny-imagenet-200-32\\train\\"
sub_folders2 = os.listdir(input_folder)

for i in range(0,len(sub_folders2)):
    i_f = input_folder2+sub_folders2[i]
    o_f = output_folder2+sub_folders[i]
    
    command2 = "copy "+i_f+"\\"+sub_folders[i]+"_boxes.txt "+o_f
    command3 = "ren "+o_f+"\\box"+" images"

    print(command2)
    print(command3)
    os.system(command2)
    os.system(command3)
# Out:
# ren E:\DevData\tiny-imagenet-200-32\train\n01443537\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01629819\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01641577\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01644900\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01698640\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01742172\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01768244\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01770393\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01774384\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01774750\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01784675\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01855672\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01882714\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01910747\box images
# ren E:\DevData\tiny-imagenet-200-32\train\n01917289\box images
# ...
